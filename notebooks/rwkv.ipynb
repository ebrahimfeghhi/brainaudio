# %%
import os
import torch
import gc

# --- 1. CRITICAL CONFIGURATION ---
# Forces the library to use the new v7 architecture
os.environ["RWKV_V7_ON"] = '1'

# IMPORTANT: Set to '0' first!
# Since you had issues with 'nvcc' (CUDA compiler) earlier, this 
# forces RWKV to run in pure PyTorch mode. It is slightly slower 
# but guaranteed to run without crashing your build environment.
os.environ["RWKV_CUDA_ON"] = '0' 

from rwkv.model import RWKV
from rwkv.utils import PIPELINE, PIPELINE_ARGS

# --- 2. LOAD MODEL ---
# Update this string to match your EXACT downloaded filename
# Example: "rwkv7-g1-2.9b-20250411-ctx4096.pth"
MODEL_FILE = "/home/ebrahim/brainaudio/llms/rwkv7-g1b-2.9b" 

print(f"Loading {MODEL_FILE}...")

# 'cuda fp16' is the standard for GPUs. 
# If you run out of VRAM, change to 'cuda fp16i8' (quantized).
model = RWKV(model=MODEL_FILE, strategy='cuda fp16')

# Load the standard tokenizer (it downloads automatically)
pipeline = PIPELINE(model, "rwkv_vocab_v20230424")

# --- 3. TEST GENERATION ---
prompt = "The quick brown fox jumps over the"
print(f"\nPrompt: '{prompt}'")

# Encode prompt
tokens = pipeline.encode(prompt)

# Forward pass (Get logic + state)
# Note: The initial state for RWKV is just None
logits, state = model.forward(tokens, None)

# Greedy decode next token
next_token_id = torch.argmax(logits, dim=-1).item()
next_word = pipeline.decode([next_token_id])

print(f"Output: '{next_word}'")
print("State Shape:", len(state), "tensors (This is your fixed state!)")
# Out:
# Loading /home/ebrahim/brainaudio/llms/rwkv7-g1b-2.9b.pth...
# Loading /home/ebrahim/brainaudio/llms/rwkv7-g1b-2.9b.pth (cuda fp16)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 27
#      23 print(f"Loading {MODEL_FILE}...")
#      25 # 'cuda fp16' is the standard for GPUs.
#      26 # If you run out of VRAM, change to 'cuda fp16i8' (quantized).
# ---> 27 model = RWKV(model=MODEL_FILE, strategy='cuda fp16')
#      29 # Load the standard tokenizer (it downloads automatically)
#      30 pipeline = PIPELINE(model, "rwkv_vocab_v20230424")
#
# File ~/brainaudio/.venv/lib/python3.12/site-packages/torch/jit/_script.py:309, in ScriptMeta.__init__.<locals>.init_then_script(self, *args, **kwargs)
#     306 @functools.wraps(original_init)
#     307 def init_then_script(self, *args, **kwargs):
#     308     num_methods = len(cls._methods)
# --> 309     original_init(self, *args, **kwargs)
#     310     added_methods_in_init = len(cls._methods) > num_methods
#     312     if type(self) == cls:
#
# File ~/brainaudio/.venv/lib/python3.12/site-packages/rwkv/model.py:245, in RWKV_x070.__init__(self, model, strategy)
#     242 else:
#     243     assert False, "currently rwkv7 strategy must be: cuda/cpu fp16/fp32/bf16"
# --> 245 temp_z = torch.load(args.MODEL_NAME + '.pth', map_location='cpu', mmap=True)
#     247 self.n_head, self.head_size = temp_z['blocks.0.att.r_k'].shape
#     248 args.head_size = self.head_size
#
# File ~/brainaudio/.venv/lib/python3.12/site-packages/torch/serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
#    1489         orig_position = opened_file.tell()
#
# File ~/brainaudio/.venv/lib/python3.12/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~/brainaudio/.venv/lib/python3.12/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ebrahim/brainaudio/llms/rwkv7-g1b-2.9b.pth.pth'
