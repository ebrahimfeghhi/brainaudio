# %%
from brainaudio.datasets.loading_data import getDatasetLoaders, SpeechDataset
import pandas as pd
import numpy as np
import re

# %%
datasetPath = ["/data2/brain2text/b2t_25/brain2text25_with_fa"]

# %%
trainLoader, testLoader,  test_data_loaders, loadedData = getDatasetLoaders(datasetPath,64,True, True)

# %%
SpeechDataset_val = SpeechDataset(loadedData['val'])
# there should be 41 days in the validation set (45 days total, 4 days don't have val data)
print(np.unique(SpeechDataset_val.days).shape)

# %%
SpeechDataset_train = SpeechDataset(loadedData['train'])
# there should be 45 days in the training set 
print(np.unique(SpeechDataset_train.days).shape)

# %%
CHAR_VOCAB = [
    "<sp>",          # space token
    "!", ",", ".", "?", "'",   # punctuation (incl. apostrophe)
] + [chr(i) for i in range(ord('a'), ord('z') + 1)]  # 'a'..'z'

# Build mappings
_CHAR_TO_ID = {c: i for i, c in enumerate(CHAR_VOCAB)}
_ID_TO_CHAR = {i: c for c, i in _CHAR_TO_ID.items()}

# Convenience indices
SPACE_ID = _CHAR_TO_ID["<sp>"]

def charToId(c: str) -> int:
    """Map raw input char to ID, normalizing space and lowercase."""
    if c == " ":
        c = "<sp>"
    c = c.lower()
    return _CHAR_TO_ID[c]

def idToChar(i: int) -> str:
    return _ID_TO_CHAR[i]

# %%
import pickle
import pandas as pd

brain2text_24_fa = pd.read_pickle("/data2/brain2text/b2t_24/brain2text24_with_fa")
brain2text_25_fa = pd.read_pickle("/data2/brain2text/b2t_25/brain2text25_with_fa")

# %%
print(list(brain2text_24_fa["train"][0].keys()))
print(list(brain2text_25_fa["train"][0].keys()))

print(len(brain2text_24_fa["train"]))
print(len(brain2text_25_fa["train"]))

print(brain2text_24_fa["train"][0]["transcriptions"])
print(brain2text_25_fa["train"][0]["transcriptions"])

print(brain2text_24_fa["train"][0]["text"])
print(brain2text_25_fa["train"][0]["text"])

print(len(brain2text_24_fa["train"][0]["text"])) # list of arrays in int32, len = 280
print(len(brain2text_25_fa["train"][0]["text"])) # list of arrays in int32, len = 288

print(len(brain2text_24_fa["train"][1]["text"])) # list of arrays in int32, len = 360
print(len(brain2text_25_fa["train"][1]["text"])) # list of arrays in int32, len = 348

for i in range(len(brain2text_24_fa["train"][1]["text"])):
    print(len(brain2text_24_fa["train"][1]["text"][i])) # max len = 500


for i in range(len(brain2text_25_fa["train"][1]["text"])):
    print(len(brain2text_25_fa["train"][1]["text"][i])) # max len = 500

# print(brain2text_24_fa["train"][0]["textLens"])
# print(brain2text_25_fa["train"][0]["textLens"])
# Out:
# ['sentenceDat', 'transcriptions', 'text', 'blockNums', 'timeSeriesLens', 'textLens', 'textPerTime', 'forced_alignments']
# ['sentenceDat', 'transcriptions', 'text', 'timeSeriesLen', 'textLens', 'forced_alignments']
# 24
# 45
# ...

# %%
print(list(brain2text_24_fa["val"][0].keys()))
print(list(brain2text_25_fa["val"]))

# %%
import re
import numpy as np
session_data = brain2text_24_fa["train"]
thisTranscription = str(session_data[0]['transcriptions'][0]).strip()
thisTranscription = re.sub(r'[^a-zA-Z\- \']', '', thisTranscription)
thisTranscription = thisTranscription.replace('--', '').lower()

txt = thisTranscription.replace('-', ' ')
chars = []
add_inter_word_symbol = True
for c in txt:
    if c == ' ':
        chars.append('<sp>')
    else:
        chars.append(c)
textLenC = len(chars)
textC = np.zeros([500], dtype=np.int32)

textC[:textLenC] = [charToId(c) + 1 for c in chars]


print(textC)
print(textLenC)
print(chars)

# %%
print(len(brain2text_24_fa["train"][0]['sentenceDat']))
print(len(brain2text_24_fa["train"][0]['transcriptions']))

print(len(brain2text_25_fa["train"][0]['sentenceDat']))
print(len(brain2text_25_fa["train"][0]['transcriptions']))

# %%
print(list(brain2text_24_fa["test"][0].keys()))
print(brain2text_24_fa["test"][0]['transcriptions'])
print(len(brain2text_24_fa["test"]))

print(len(brain2text_24_fa["val"]))
# Out:
# ['sentenceDat', 'transcriptions', 'text', 'blockNums', 'timeSeriesLens', 'textLens', 'textPerTime']
# ...

# %%
brain2text24_fa_c = {}
brain2text24_fa_c_train = []
brain2text24_fa_c_val = []

max_seq_len = 500

for idx in range(len(brain2text_24_fa["train"])):
    session = brain2text_24_fa["train"][idx] # dictionary
    textC = []
    textLensC = []
    for x in range(len(session['transcriptions'])):
        thisTranscription = str(session['transcriptions'][x]).strip()
        thisTranscription = re.sub(r'[^a-zA-Z\- \']', '', thisTranscription)
        thisTranscription = thisTranscription.replace('--', '').lower()

        txt = thisTranscription.replace('-', ' ')
        chars = []
        for c in txt:
            if c == ' ':
                chars.append('<sp>')
            else:
                chars.append(c)
        chars.append('<sp>')

        seq_len_c = len(chars)
        seq_ids_c = np.zeros([max_seq_len], dtype=np.int32)
        seq_ids_c[:seq_len_c] = [charToId(c) + 1 for c in chars]

        textC.append(np.array(seq_ids_c))
        textLensC.append(seq_len_c)

    new_dict = session.copy()
    new_dict['textC'] = textC
    new_dict['textLensC'] = textLensC
    brain2text24_fa_c_train.append(new_dict)  


for idx in range(len(brain2text_24_fa["val"])):
    session = brain2text_24_fa["val"][idx] # dictionary
    textC = []
    textLensC = []
    for x in range(len(session['transcriptions'])):
        thisTranscription = str(session['transcriptions'][x]).strip()
        thisTranscription = re.sub(r'[^a-zA-Z\- \']', '', thisTranscription)
        thisTranscription = thisTranscription.replace('--', '').lower()

        txt = thisTranscription.replace('-', ' ')
        chars = []
        for c in txt:
            if c == ' ':
                chars.append('<sp>')
            else:
                chars.append(c)
        chars.append('<sp>')

        seq_len_c = len(chars)
        seq_ids_c = np.zeros([max_seq_len], dtype=np.int32)
        seq_ids_c[:seq_len_c] = [charToId(c) + 1 for c in chars]

        textC.append(np.array(seq_ids_c))
        textLensC.append(seq_len_c)

    new_dict = session.copy()
    new_dict['textC'] = textC
    new_dict['textLensC'] = textLensC
    brain2text24_fa_c_val.append(new_dict) 

brain2text24_fa_c['train'] = brain2text24_fa_c_train
brain2text24_fa_c['val'] = brain2text24_fa_c_val
brain2text24_fa_c['test'] = brain2text_24_fa["test"]

# %%
with open("/data2/brain2text/b2t_24/brain2text24_with_fa_char", "wb") as handle:
    pickle.dump(brain2text24_fa_c, handle)

# %%
print(brain2text24_fa_c_train[0].keys())
# print(brain2text24_fa_c_train[0]['textC'])
# print(brain2text24_fa_c_train[0]['text'])
print(brain2text24_fa_c_train[0]['textLensC'])
# Out:
# dict_keys(['sentenceDat', 'transcriptions', 'text', 'blockNums', 'timeSeriesLens', 'textLens', 'textPerTime', 'forced_alignments', 'textC', 'textLensC'])
# ...

# %%
brain2text25_fa_c = {}
brain2text25_fa_c_train = []
brain2text25_fa_c_val = []

max_seq_len = 500

for idx in range(len(brain2text_25_fa["train"])):
    session = brain2text_25_fa["train"][idx] # dictionary
    textC = []
    textLensC = []
    for x in range(len(session['transcriptions'])):
        thisTranscription = str(session['transcriptions'][x]).strip()
        thisTranscription = re.sub(r'[^a-zA-Z\- \']', '', thisTranscription)
        thisTranscription = thisTranscription.replace('--', '').lower()

        txt = thisTranscription.replace('-', ' ')
        chars = []
        for c in txt:
            if c == ' ':
                chars.append('<sp>')
            else:
                chars.append(c)
        chars.append('<sp>')

        seq_len_c = len(chars)
        seq_ids_c = np.zeros([max_seq_len], dtype=np.int32)
        seq_ids_c[:seq_len_c] = [charToId(c) + 1 for c in chars]

        textC.append(np.array(seq_ids_c))
        textLensC.append(seq_len_c)

    new_dict = session.copy()
    new_dict['textC'] = textC
    new_dict['textLensC'] = textLensC
    brain2text25_fa_c_train.append(new_dict) 

for idx in range(len(brain2text_25_fa["val"])):
    session = brain2text_25_fa["val"][idx]
    if session is None:
        brain2text25_fa_c_val.append(None)
        continue
    textC = []
    textLensC = []
    for x in range(len(session['transcriptions'])):
        thisTranscription = str(session['transcriptions'][x]).strip()
        thisTranscription = re.sub(r'[^a-zA-Z\- \']', '', thisTranscription)
        thisTranscription = thisTranscription.replace('--', '').lower()

        txt = thisTranscription.replace('-', ' ')
        chars = []
        for c in txt:
            if c == ' ':
                chars.append('<sp>')
            else:
                chars.append(c)
        chars.append('<sp>')

        seq_len_c = len(chars)
        seq_ids_c = np.zeros([max_seq_len], dtype=np.int32)
        seq_ids_c[:seq_len_c] = [charToId(c) + 1 for c in chars]

        textC.append(np.array(seq_ids_c))
        textLensC.append(seq_len_c)

    new_dict = session.copy()
    new_dict['textC'] = textC
    new_dict['textLensC'] = textLensC
    brain2text25_fa_c_val.append(new_dict) 


brain2text25_fa_c['train'] = brain2text25_fa_c_train
brain2text25_fa_c['val'] = brain2text25_fa_c_val
brain2text25_fa_c['test'] = brain2text_25_fa["test"]

# %%
with open("/data2/brain2text/b2t_25/brain2text25_with_fa_char", "wb") as handle:
    pickle.dump(brain2text25_fa_c, handle)

# %%
brain2text_24_fa = pd.read_pickle("/data2/brain2text/b2t_24/brain2text24_with_fa_char")
brain2text_25_fa = pd.read_pickle("/data2/brain2text/b2t_25/brain2text25_with_fa_char")

# %%
print(brain2text_24_fa["train"][0].keys())
print(brain2text_25_fa["train"][1].keys())
# Out:
# dict_keys(['sentenceDat', 'transcriptions', 'text', 'blockNums', 'timeSeriesLens', 'textLens', 'textPerTime', 'forced_alignments', 'textC', 'textLensC'])
# dict_keys(['sentenceDat', 'transcriptions', 'text', 'timeSeriesLen', 'textLens', 'forced_alignments', 'textC', 'textLensC'])
