# %%
import pandas as pd

# --- Configuration ---
input_csv_path = '/home/lionelhu/brainaudio/results/test_files/transformer/best_chunked_transformer_combined_seed_9_llama_1b_02_11_2313_test_1615175.csv' # Replace with your actual file name
output_txt_path = '../results/test_files/best_chunked_transformer_seed_9_b2t24_1b.txt'
# ---------------------

# 1. Read the CSV
# We assume the file has a header. Based on your image, the text column is named 'text'.
df = pd.read_csv(input_csv_path)

# 2. Extract the 'text' column
# This automatically drops the 'id' column
sentences = df['text']

# 3. Save to .txt
# index=False removes the row numbers
# header=False removes the column name
sentences.to_csv(output_txt_path, index=False, header=False)

print(f"Successfully extracted {len(sentences)} sentences to {output_txt_path}")
# Out:
# Successfully extracted 1200 sentences to ../results/test_files/best_chunked_transformer_seed_9_b2t24_1b.txt
