# %%
import pandas as pd

# --- Configuration ---
input_csv_path = '/home/lionelhu/brainaudio/results/test_files/b2t_24/neurips_b2t_24_chunked_unidirectional_transformer_5to20_sec_seed_4_lc7.5_02_18_2007_test_1227138.csv' # Replace with your actual file name
output_txt_path = '../results/b2t_24_test_results/neurips_b2t_24_unidirectional_transformer_lc7.5_seed_4.txt'
# ---------------------

# 1. Read the CSV
# We assume the file has a header. Based on your image, the text column is named 'text'.
df = pd.read_csv(input_csv_path)

# 2. Extract the 'text' column
# This automatically drops the 'id' column
sentences = df['text']

# 3. Save to .txt
# index=False removes the row numbers
# header=False removes the column name
sentences.to_csv(output_txt_path, index=False, header=False)

print(f"Successfully extracted {len(sentences)} sentences to {output_txt_path}")
# Out:
# Successfully extracted 1200 sentences to ../results/b2t_24_test_results/neurips_b2t_24_unidirectional_transformer_lc7.5_seed_4.txt
