# %%
# --- 3. Convert ---
from brainaudio.inference.decoder.ngram_lm import NGramGPULanguageModel

nemo_path= "/home/ebrahim/brainaudio/creating_n_gram_lm/phoneme_10gram.nemo"

# vocab_size=40 for the 40 phonemes (no blank in LM)
lm = NGramGPULanguageModel.from_nemo(
    lm_path=nemo_path,
    vocab_size=40,
    map_location="cpu"
)
# Out:
# [NeMo I 2025-12-29 18:14:55 save_restore_connector:284] Model NGramGPULanguageModel was successfully restored from /home/ebrahim/brainaudio/creating_n_gram_lm/phoneme_10gram.nemo.
