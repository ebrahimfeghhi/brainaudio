# %%
'/home/lionelhu/brainaudio/results/seed_1_02_04_1650_1374861.npy'
'/home/lionelhu/brainaudio/results/seed_2_02_04_1650_1379991.npy'
'/home/lionelhu/brainaudio/results/seed_3_02_04_1650_1388091.npy'
'/home/lionelhu/brainaudio/results/seed_4_02_04_1650_1393672.npy'
'/home/lionelhu/brainaudio/results/seed_5_02_04_1650_1399014.npy'
'/home/lionelhu/brainaudio/results/seed_6_02_04_1650_1404442.npy'

# %%
import numpy as np

np.load('/home/lionelhu/brainaudio/results/seed_1_02_04_1650_1374861.npy')
# Out:
# array([0.14522214, 0.10903985, 0.10076358, 0.16632712, 0.11793577,
#        0.12577609, 0.1179021 , 0.13256959, 0.15658023, 0.22022556,
#        0.10604534, 0.11048213, 0.11830595, 0.11007868, 0.1644994 ,
#        0.14717443, 0.14141964, 0.1278002 , 0.10784342, 0.09607686,
#        0.12612616, 0.11859848, 0.20184924, 0.1778081 , 0.12956594,
#        0.14319144, 0.13080395, 0.1235751 , 0.10769789, 0.19182525,
#        0.10712889, 0.11143937, 0.11206127, 0.13942416, 0.12317396,
#        0.16708197, 0.12328643, 0.18490372, 0.10835275, 0.13730419,
#        0.15364771, 0.114934  , 0.10501036, 0.12180811, 0.13266642,
#        0.10387181, 0.14130433, 0.11909943, 0.16889158, 0.11994493,
#        0.12882637, 0.12102058, 0.15681682, 0.13446617, 0.14704887,
#        0.14499647, 0.13431233, 0.12564158, 0.18421093, 0.12510285,
#        0.11255474, 0.14862185, 0.12220308, 0.10446956, 0.15079795,
#        0.10848135, 0.13879582, 0.18064167, 0.14552089, 0.18571402,
# ...

# %%
import pandas as pd
input_csv_path = "/home/lionelhu/brainaudio/results/seed_1_02_04_1650_1374861.csv"
df = pd.read_csv(input_csv_path)

print(df)
# Out:
#       id                                               text
# 0      0                              the artist recounted.
# 1      1        guests purchase several signed lithographs.
# 2      2         the rules were made in interest collusion.
# 3      3  does house need make love to be completely ele...
# 4      4  the tooth fairy forgot to come when roger's to...
# ..   ...                                                ...
# 875  875                           your decision important.
# 876  876              getting max seats for the price sets.
# 877  877                   if you have any tips whatsoever.
# 878  878                                   literary movies.
# 879  879                            i can't remember where.
#
# [880 rows x 2 columns]
